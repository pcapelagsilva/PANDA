# %%
import pandas as pd
import numpy as np

# 1. Criando um mini dataset de vendas com problemas
dados = {
    'produto': ['Teclado', 'Mouse', 'Monitor', 'Cadeira'],
    'preco': ['150.00', '80.50', np.nan, '450.00'], # Temos um valor faltante aqui
    'vendedor': ['Ana', np.nan, 'Carlos', 'Ana']    # E outro aqui
}

df = pd.DataFrame(dados)

print("--- DataFrame Original ---")
display(df) # O 'display' deixa a tabela bonitinha no Notebook

# --- SEU DESAFIO ---
# A) Substitua os valores nulos (NaN) da coluna 'vendedor' por "Staff"
# B) Converta a coluna 'preco' para float (número decimal)
# C) Preencha o preço faltante com a média dos outros preços

# Tente resolver e rode a célula!
# Out:
# --- DataFrame Original ---
#    produto   preco vendedor
# 0  Teclado  150.00      Ana
# 1    Mouse   80.50      NaN
# 2  Monitor     NaN   Carlos
# 3  Cadeira  450.00      Ana
